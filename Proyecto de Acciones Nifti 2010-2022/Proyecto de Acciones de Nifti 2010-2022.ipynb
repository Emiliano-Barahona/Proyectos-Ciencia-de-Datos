# %%
# Explanation of the cell:
    #In this cell I import all the libraries that I will use in the future:
        # Line 1:
            # Function: "Import _ as _" / Library: "pandas"
            # Utlity: Import the pandas library
        # Line 2:
            # Function: "Import _" / Library: "pandas_profiling"
            # Utility: Import the "pandas_profiling" module from the "pandas" library
        # Line 3:
            # Function: "Import _ as _" / Library: "matplotlib" / Module: "pyplot"
            # utility: Import the "Matplotlib" library and its "pyplot" module
        # Line 4:
            # Function: "Import _ as _" / Library: "seaborn"
            # Utility: Import the "seaborn" library

import pandas as pd
import pandas_profiling
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Explanation of the cell:
    #In this cell I import and read the csv file transforming it into a variable:
        # Line 1:
            # Function: "pd.read_csv"
            # Utility: Import and read a csv file transforming it to a variable
        # Line 2:
            # Function: ".head"
            # Utility: Data display in table

df = pd.read_csv("sample_data/acciones.csv")
df.head(50)
# Out:
#           DATE  TATASTEEL   WIPRO  ...  BAJAJ-AUTO  ASIANPAINT  UPL
# 0   2010-01-11     591.90  423.70  ...     1530.75     2705.05  NaN
# 1   2010-01-12     613.55  414.70  ...     1571.20     2680.40  NaN
# 2   2010-02-11     599.05  433.85  ...     1548.75     2792.80  NaN
# 3   2010-02-12     622.75  426.05  ...     1574.30     2651.85  NaN
# 4   2010-03-11     609.60  434.70  ...     1582.35     2694.90  NaN
# 5   2010-03-12     614.55  427.60  ...     1600.15     2670.05  NaN
# 6   2010-04-11     621.50  436.75  ...     1610.35     2663.05  NaN
# 7   2010-05-11     623.55  438.05  ...     1614.35     2688.95  NaN
# 8   2010-06-12     635.05  430.65  ...     1585.45     2682.10  NaN
# 9   2010-07-12     639.35  434.95  ...     1606.90     2707.65  NaN
# 10  2010-08-11     633.20  431.20  ...     1600.45     2740.85  NaN
# 11  2010-08-12     624.25  435.30  ...     1565.70     2658.05  NaN
# 12  2010-09-11     641.30  431.65  ...     1610.00     2755.40  NaN
# ...

# %%
# Explanation of the cell:
    #In this cell I show the available columns
        #Line 1:
            # Function: ".columns"
            # Utility: Sample of available columns


(df.columns)
# Out:
# Index(['DATE', 'TATASTEEL', 'WIPRO', 'TITAN', 'ULTRACEMO', 'TECHM', 'RELIANCE',
#        'SHREECEM', 'SUNPHARMA', 'TATAMOTORS', 'TCS', 'SBIN', 'NESTLEIND',
#        'NTPC', 'M&M', 'MARUTI', 'ONGC', 'POWERGRID', 'JSWSTEEL', 'KOTAKBANK',
#        'LT', 'ICICIBANK', 'INDUSBANK', 'INFY', 'IOC', 'ITC', 'HEROMOTOCO',
#        'HINDALCO', 'HINDUNILVR', 'HCLTECH', 'HDFCBANK', 'HDFC', 'DRREDDYS',
#        'EICHERMOTOR', 'GRASIM', 'CIPLA', 'COALINDIA', 'BPCL', 'BRITANNIA',
#        'ADANIPORTS', 'BAJAJFINSERV', 'BAJAJFINANCE', 'BHARTIARTL', 'AXISBANK',
#        'BAJAJ-AUTO', 'ASIANPAINT', 'UPL'],
#       dtype='object')

# %%
# Explanation of the cell:
    #In this cell I describe the data frame:
        #Line 1:
            # Function: ".describe"
            # Usefulness: Describe the main features of the data frame (including the mean and median)


df.describe()
# Out:
#          TATASTEEL        WIPRO  ...   ASIANPAINT          UPL
# count  2711.000000  2711.000000  ...  2711.000000  1959.000000
# mean    482.953707   418.266230  ...  1854.409314   572.459622
# std     207.301401   119.474173  ...  1185.490852   195.799043
# min     198.250000   162.350000  ...   392.000000   153.800000
# 25%     360.525000   312.000000  ...   895.925000   432.350000
# 50%     436.850000   419.750000  ...  1388.600000   576.750000
# 75%     563.025000   536.400000  ...  2706.900000   727.275000
# max    1519.400000   708.250000  ...  5213.100000  1034.500000
#
# [8 rows x 46 columns]

# %%
# Explanation of the cell:
    #In this cell I transform the cell "date" from an object data type to a date data type:
        # Line 1:
            # Function: "pd.to_datatime"
            # Usefulness: Pass a column of type object to type date
        # Line 2:
            # Function: ".info ()"
            # Usefulness: Show a report of the existing columns on: - Their data types
                                                                  # - Amount of them
                                                                  # - Amount of non-null values
                                                                  # - Memory they occupy

df["DATE"] = pd.to_datetime(df["DATE"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2711 entries, 0 to 2710
# Data columns (total 47 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   DATE          2711 non-null   datetime64[ns]
#  1   TATASTEEL     2711 non-null   float64
#  2   WIPRO         2711 non-null   float64
#  3   TITAN         2711 non-null   float64
#  4   ULTRACEMO     2711 non-null   float64
#  5   TECHM         2711 non-null   float64
#  6   RELIANCE      2711 non-null   float64
#  7   SHREECEM      2711 non-null   float64
#  8   SUNPHARMA     2711 non-null   float64
#  9   TATAMOTORS    2711 non-null   float64
#  10  TCS           2711 non-null   float64
#  11  SBIN          2711 non-null   float64
#  12  NESTLEIND     2711 non-null   float64
#  13  NTPC          2711 non-null   float64
#  14  M&M           2711 non-null   float64
#  15  MARUTI        2711 non-null   float64
#  16  ONGC          2711 non-null   float64
# ...

# %%
# Explanation of the cell:
    #In this cell I define a new variable that contains the columns of the data frame and I do a for loop to be able to
    # make all the graphs of the actions:
        # Line 1:
            # Function: "_ = [" _, _, _ "]"
            # Utility: Declare a variable that is equal to these columns
        # Line 9:
            # Function: "_ = 1"
            # Utility: Declare a variable that is equal to a number (in this case 1)
        # Line 11:
            # Function: "for _ in _"
            # Utility: Loop through the elements of an iterable object and execute a block of code
                # Line 12:
                    # Function: "plt.figure (figsize = (n1, n2))"
                    # Utility: Create a graph with the following measurements (in this case they are 5 and 200)
                # Line 13:
                    # Function: "a + = 1"
                    # Utility: Add this amount to the variable "a"
                # Line 14:
                    # Function: "plt.subplot"
                    # Utility: Make a subgraph
                # Line 15:
                    # Function: "_ = df [" _ "]"
                    # Utility: Declare a variable that is equivalent to this column
                # Line 16:
                    # Function: "_ = df [" i "]"
                    # Utility: Declare a variable that is equivalent to this column
                # Line 17:
                    # Function: "plt.plot (x, y)"
                    # Utility: Create a graph with 2 variables (in this case "x" and "y")
                # Line 18:
                    # Function: "plt.xlabel ()"
                    # Utility: Enter the name of the "x" axis
                # Line 19:
                    # Function: "plt.ylabel ()"
                    # Utility: Enter the name of the "y" axis
                # Line 20:
                    # Function: "plt.title ()"
                    # Utility: Enter the title of the graph
                # Line 21:
                    # Function: "plt.figure ()"
                    # Utility: Show the chart made








actions = ['TATASTEEL', 'WIPRO', 'TITAN', 'ULTRACEMO', 'TECHM', 'RELIANCE',
       'SHREECEM', 'SUNPHARMA', 'TATAMOTORS', 'TCS', 'SBIN', 'NESTLEIND',
       'NTPC', 'M&M', 'MARUTI', 'ONGC', 'POWERGRID', 'JSWSTEEL', 'KOTAKBANK',
       'LT', 'ICICIBANK', 'INDUSBANK', 'INFY', 'IOC', 'ITC', 'HEROMOTOCO',
       'HINDALCO', 'HINDUNILVR', 'HCLTECH', 'HDFCBANK', 'HDFC', 'DRREDDYS',
       'EICHERMOTOR', 'GRASIM', 'CIPLA', 'COALINDIA', 'BPCL', 'BRITANNIA',
       'ADANIPORTS', 'BAJAJFINSERV', 'BAJAJFINANCE', 'BHARTIARTL', 'AXISBANK',
       'BAJAJ-AUTO', 'ASIANPAINT', 'UPL']
a = 1

for i in actions:
    plt.figure(figsize=(5,200))
    a += 1
    plt.subplot(47,1,a)
    x = df["DATE"]
    y = df[i] 
    plt.plot(x, y)
    plt.xlabel("Años")
    plt.ylabel(f"Variación del precio de la acción {i} (Dolares)")
    plt.title(f"Accion de {i} desde 2010 a 2021")
    plt.figure()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:62: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:71: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# ...

# %%
#And finally to finish this project, next I will analyze
#the graphics previously made:
				# Graphic of "TATASTEEL": Interval: Increasing
												 			  # Years: 2010 - 2022
												 			  # Lowest Price: $ 200
												 			  # Highest Price: $ 1500
												 			  # 2010 Price: $ 600
												  	 	 # Price 2022: $ (+ 1400)
				#  Graphic of "WIPRO": Interval Type: Increasing
														 # Years: 2010 - 2022
														 # Lowest Price: $ 100
														 # Highest Price: $ 700
														 # 2010 Price: $ 400
       											 # 2022 Price: $ 700
				# Graphic of "TIAN": Interval Type: Decreasing
											 		 # Years: 2010 - 2022
												 	 # Lowest Price: $ 100
													 # Highest Price: $ 4800
													 # 2010 Price: $ 3800
													 # 2022 Price: $ 2500
				# Graphic of "ULTRACEMO": Interval Type: Increasing
																# Years: 2010 - 2022
																# Lowest Price: $ 1000
																# Highest Price: $ 8000
																# 2010 Price: $ 5500
																# 2022 Price: $ 8000
				# Graphic of "TECHM": Interval Type: Increasing
														# Years: 2010 - 2022
														# Lowest Price: $ 250
														# Highest Price: $ 2800
														# 2010 Price: $ 750
														# 2022 Price: $ 1500
				# Graphic of "RELIANCE": Interval Type: Increasing
															 # Years: 2010 - 2022
															 # Lowest Price: $ 700
															 # Highest Price: $ 2700
															 # 2010 Price: $ 1000
															 # 2022 Price: $ 2700
				# Graphic of "SCHREECEM": Interval Type: Increasing
																# Years: 2010 - 2022
																# Lowest Price: $ 2500
																# Highest Price: $ 30200
																# 2010 Price: $ 2500
																# 2022 Price: $ 30200
				# Graphic of "SUNPHARMA": Interval Type: Decreasing
																# Years: 2010 - 2022
																# Lowest Price: $ 300
																# Highest Price: $ 2300
																# 2010 Price: $ 2200
																# 2022 Price: $ 800
				# Graphic of "TATAMOTORS": Interval Type: Decreasing
																 # Years: 2010 - 2022
																 # Lowest Price: $ 75
															   # Highest Price: $ 1400
																 # 2010 Price: $ 1200
																 # 2022 Price: $ 500
				# Graphic of "TCS": Interval Type: Increasing
													# Years: 2010 - 2022
													# Lowest Price: $ 1000
													# Highest Price: $ 4000
													# 2010 Price: $ 1000
													# 2022 Price: $ 4000
				# Graphic of "SBIN": Interval Type: Increasing
													 # Years: 2010 - 2022
													 # Lowest Price: $ 200
													 # Highest Price: $ 3500
													 # 2010 Price: $ 3200
													 # 2022 Price: $ 500
				# Graphic of "NESTLEIND": Interval Type: Increasing
																# Years: 2010 - 2022
																# Lowest Price: $ 3500
																# Highest Price: $ 20200
																# 2010 Price: $ 3750
																# 2022 Price: $ 20200
				# Graphic of "NTPC": Interval Type: Decreasing
													 # Years: 2010 - 2022
													 # Lowest Price: $ 80
 													 # Highest Price: $ 220
													 # 2010 Price: $ 190
	 												 # 2022 Price: $ 140
				# Graphic of "M&M": Interval Type: Increasing
													# Years: 2010 - 2022
													# Lowest Price: $ 200
													# Highest Price: $ 1500
													# 2010 Price: $ 800
													# 2022 Price: $ 850
				# Graphic of "MARUTI": Interval Type: Increasing
														 # Years: 2010 - 2022
														 # Lowest Price: $ 1000
														 # Highest Price: $ 10000
														 # 2010 Price: $ 1500
														 # 2022 Price: $ 7500
				# Graphic of "ONGC": Interval Type: Decreasing
													 # Years: 2010 - 2022
													 # Lowest Price: $ 70
													 # Highest Price: $ 1400
													 # 2010 Price: $ 1300
													 # 2022 Price: $ 150
				# Graphic of "POWERGRID": Interval Type: Increasing
																# Years: 2010 - 2022
																# Lowest Price: $ 50
																# Highest Price: $ 250
																# 2010 Price: $ 190
																# 2022 Price: $ 260
				# Graphic of "JSWSTEEL": Interval Type: Decreasing
															 # Years: 2010 - 2022
															 # Lowest Price: $ 200
															 # Highest Price: $ 1800
															 # 2010 Price: $ 1300
															 # 2022 Price: $ 750
				# Graphic of "KOTAKBANK": Interval Type: Increasing
																# Years: 2010 - 2022
																# Lowest Price: $ 250
																# Highest Price: $ 2100
																# 2010 Price: $ 500
																# 2022 Price: $ 2100
				# Graphic of "LT": Interval Type: Decreasing
												 # Years: 2010 - 2022
												 # Lowest Price: $ 600
												 # Highest Price: $ 2175
												 # 2010 Price: $ 2000
												 # 2022 Price: $ 1800
				# Graphic of "ICICIBANK": Interval Type: Decreasing
																# Years: 2010 - 2022
																# Lowest Price: $ 200
																# Highest Price: $ 1800
																# 2010 Price: $ 1200
																# 2022 Price: $ 700
				# GraphIC of "INDUSBANK": Interval Type: Increasing
																# Years: 2010 - 2022
																# Lowest Price: $ 250
																# Highest Price: $ 2000
																# 2010 Price: $ 300
																# 2022 Price: $ 1250
				# Graphic of "INFY": Interval Type: Decreasing
													 # Years: 2010 - 2022
													 # Lowest Price: $ 550
													 # Highest Price: $ 4300
													 # 2010 Price: $ 2750
													 # 2022 Price: $ 1750
				# Graphic of "IOC": Interval Type: Decreasing
													# Years: 2010 - 2022
													# Lowest Price: $ 50
													# Highest Price: $ 670
													# 2010 Price: $ 400
													# 2022 Price: $120
				# Graphic of "ITC": Interval Type: Increasing
													# Years: 2010 - 2022
													# Lowest Price: $ 150
													# Highest Price: $ 250
													# 2010 Price: $ 175
													# 2022 Price: $ 390
				# Graphic of "HEROMOTOCO": Interval Type: Increasing
																 # Years: 2010 - 2022
																 # Lowest Price: $ 1500
																 # Highest Price: $ 4000
																 # 2010 Price: $ 2200
																 # 2022 Price: $ 3500
				# Graphic of "HINDALCO": Interval Type: Increasing
															 # Years: 2010 - 2022
															 # Lowest Price: $ 50
															 # Highest Price: $ 520
 															 # 2010 Price: $ 210
															 # 2022 Price: $ 520
				# Graphic of "HINDUNILVR": Interval Type: Increasing
																 # Years: 2010 - 2022
																 # Lowest Price: $ 250
																 # Highest Price: $ 2900
																 # 2010 Price: $ 250
																 # 2022 Price: $ 2900
				# Graphic of "HCLTECH": Interval Type: Increasing
														 # Years: 2010 - 2022
														 # Lowest Price: $ 250
														 # Highest Price: $ 2100
													   # 2010 Price: $ 250
														 # 2022 Price: $ 1375
				# Graphic of "HDFCBANK": Interval Type: Decreasing
														 # Years: 2010 - 2022
 														 # Lowest Price: $ 450
														 # Highest Price: $ 2500
														 # 2010 Price: $ 2400
														 # 2022 Price: $ 1600
				# Graphic of "HDFC" : Interval Type: Increasing
														 # Years: 2010 - 2022
														 # Lowest Price: $ 600
														 # Highest Price: $ 250
														 # 2010 Price: $ 700
														 # 2022 Price: $ 2900
				# Graphic of "DRREDDYS": Interval Type: Increasing
															 # Years: 2010 - 2022
															 # Lowest Price: $ 1350
															 # Highest Price: $ 5000 (Approximately)
															 # 2010 Price: $ 1800
															 # Price 2022: $ 5000 (Approximately)
				# Graphic of "EICHERMOTOR": Interval Type: Increasing
																	# Years: 2010 - 2022
																	# Lowest Price: $ 2000
																	# Highest Price: $ 37000
																	# 2010 Price: $ 2000
																	# 2022 Price: $ 3000
				# Graph of "GRASIM": Interval Type: Decreasing
													 # Years: 2010 - 2022
													 # Lowest Price: $ 500
													 # Highest Price: $ 5200
													 # 2010 Price: $ 2200
													 # 2022 Price: $ 1800
				# Graphic of "CIPLA": Interval Type: Increasing
														# Years: 2010 - 2022
														# Lowest Price: $ 280
													  # Highest Price: $ 1000
														# 2010 Price: $ 380
														# 2022 Price: $ 1000
				# Graphic of "COALINDIA": Interval Type: Decreasing
																# Years: 2010 - 2022
																# Lowest Price: $ 120
																# Highest Price: $ 450
																# 2010 Price: $ 325
																# 2022 Price: $ 190
				# Graph of "BPCL": Interval Type: Decreasing
													# Years: 2010 - 2022
													# Lowest Price: $ 200
													# Highest Price: $ 1300
													# 2010 Price: $ 700
													# 2022 Price: $ 500
				# Graphic of "BRITANNIA": Interval Type: Increasing
																# Years: 2010 - 2022
																# Lowest Price: $ 400
																# Highest Price: $ 7000
																# 2010 Price: $ 400
																# 2022 Price: $ 7000
				# Graphic of "ADANIPORTS": Interval Type: Increasing
																 # Years: 2010 - 2022
																 # Lowest Price: $ 100
																 # Highest Price: $ 900
																 # 2010 Price: $ 110
																 # 2022 Price: $ 850
				# Graphic of "BAJAJFINSERV": Interval Type: Increasing
																	 # Years: 2010 - 2022
																	 # Lowest Price: $ 1200
																	 # Highest Price: $ 20000
																	 # 2010 Price: $ 1200
																	 # 2022 Price: $ 20000
				# Graph of "BAJAJFINANCE": Interval Type: Increasing
																 # Years: 2010 - 2022
																 # Lowest Price: $ 1000
																 # Highest Price: $ 13000
																 # 2010 Price: $ 1000
																 # 2022 Price: $ 7800
				# Graphic of "BHARTIARLT": Interval Type: Increasing
																 # Years: 2010 - 2022
																 # Lowest Price: $ 200
																 # Highest Price: $ 750
																 # 2010 Price: $ 350
																 # 2022 Price: $ 750
				# Graphic of "AXISBANK": Interval Type: Decreasing
															 # Years: 2010 - 2022
															 # Lowest Price: $ 375
															 # Highest Price: $ 2000
															 # 2010 Price: $ 1500
															 # 2022 Price: $ 750
				# Graphic of "BAJAJ-AUTO": Interval Type: Increasing
																 # Years: 2010 - 2022
																 # Lowest Price: $ 900
																 # Highest Price: $ 4200
																 # 2010 Price: $ 1500
																 # Price 2022: $ 4000 (Approximately)
				# Graphic of "ASIANPAINT": Interval Type: Increasing
																 # Years: 2010 - 2022
																 # Lowest Price: $ 300
																 # Highest Price: $ 5000
																 # 2010 Price: $ 2800
																 # 2022 Price: $ 3200
				# Graphic of "UPL": Interval Type: Increasing
													# Years: 2010 - 2022
													# Lowest Price: $ 180
													# Highest Price: $ 1100
													# 2010 Price: $ 180
													# 2022 Price: $ 800
